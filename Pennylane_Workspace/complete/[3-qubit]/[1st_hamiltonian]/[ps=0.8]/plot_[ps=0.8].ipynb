# %%
import matplotlib.pyplot as plt
from IPython.display import display, Latex
from matplotlib.ticker import MultipleLocator
import numpy as np  # Original numpy

import pandas as pd
from enum import Enum

# %%
class INDEX(Enum):
    PHI = 0
    CFI = 1
    
    THETA_X = 2
    
    PHI_Z1 = 3
    PHI_Z2 = 4
    PHI_Z3 = 5
    
    TAU_1 = 6
    TAU_2 = 7

# %%
data_0 = np.load('result_0_1st.npy')
data_1 = pd.read_csv('[0.005].csv').values
data_2 = pd.read_csv('[0.05].csv').values
data_3 = pd.read_csv('[0.1].csv').values
data_4 = pd.read_csv('[0.5].csv').values

# %%
data_0[0][:, INDEX.TAU_1.value]
# Out:
# array([0.1832272 , 0.18347324, 0.18392037, ..., 0.18481962, 0.18481569,
#        0.18481566])

# %%
data_4[10, 1]
# Out:
# 0.24255213141441345

# %%
plt.plot(data_0[0][:, INDEX.PHI.value], data_0[0][:, INDEX.CFI.value], label = f'$\\tau$ = {0}')
plt.plot(data_1[:, INDEX.PHI.value], data_1[:, INDEX.CFI.value], label = f'$\\tau$ = {0.005}')
plt.plot(data_2[:, INDEX.PHI.value], data_2[:, INDEX.CFI.value], label = f'$\\tau$ = {0.05}')
plt.plot(data_3[:, INDEX.PHI.value], data_3[:, INDEX.CFI.value], label = f'$\\tau$ = {0.1}')
plt.plot(data_4[:, INDEX.PHI.value], data_4[:, INDEX.CFI.value], label = f'$\\tau$ = {0.5}')
plt.title(f'CFI at $\gamma_{{ps}} = {0.8}$')
plt.xlabel('Time')
plt.ylabel('CFI')
plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(data_0[0][:, INDEX.PHI.value], data_0[0][:, INDEX.THETA_X.value], label = f'$\\tau$ = {0}')
plt.plot(data_1[:, INDEX.PHI.value], data_1[:, INDEX.THETA_X.value], label = f'$\\tau$ = {0.005}')
plt.plot(data_2[:, INDEX.PHI.value], data_2[:, INDEX.THETA_X.value], label = f'$\\tau$ = {0.05}')
plt.plot(data_3[:, INDEX.PHI.value], data_3[:, INDEX.THETA_X.value], label = f'$\\tau$ = {0.1}')
plt.plot(data_4[:, INDEX.PHI.value], data_4[:, INDEX.THETA_X.value], label = f'$\\tau$ = {0.5}')

plt.yticks(
    [-np.pi, -np.pi/2, 0, np.pi/2, np.pi, (3*np.pi)/2, 2*np.pi], 
    ['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$', '$3\pi/2$', '$2\pi$']
)
plt.ylim(-np.pi/2, 1*np.pi/2)
plt.title(f'Optimized $\\theta_{{x}}$')
plt.xlabel('Time')
plt.ylabel('RAD')
plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(data_0[0][:, INDEX.PHI.value], data_0[0][:, INDEX.PHI_Z1.value], label = f'$\\tau$ = {0}')
plt.plot(data_1[:, INDEX.PHI.value], data_1[:, INDEX.PHI_Z1.value], label = f'$\\tau$ = {0.005}')
plt.plot(data_2[:, INDEX.PHI.value], data_2[:, INDEX.PHI_Z1.value], label = f'$\\tau$ = {0.05}')
plt.plot(data_3[:, INDEX.PHI.value], data_3[:, INDEX.PHI_Z1.value], label = f'$\\tau$ = {0.1}')
plt.plot(data_4[:, INDEX.PHI.value], data_4[:, INDEX.PHI_Z1.value], label = f'$\\tau$ = {0.5}')

plt.yticks(
    [-np.pi, -np.pi/2, 0, np.pi/2, np.pi, (3*np.pi)/2, 2*np.pi, 5*np.pi/2, 3*np.pi], 
    ['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$', '$3\pi/2$', '$2\pi$', '$5\pi/2$', '$3\pi$']
)

plt.ylim(np.pi/2, 6*np.pi/2)
plt.title(f'Optimized $\\phi_{{z1}}$')
plt.xlabel('Time')
plt.ylabel('RAD')
plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(data_0[0][:, INDEX.PHI.value], data_0[0][:, INDEX.PHI_Z2.value], label = f'$\\tau$ = {0}')
plt.plot(data_1[:, INDEX.PHI.value], data_1[:, INDEX.PHI_Z2.value], label = f'$\\tau$ = {0.005}')
plt.plot(data_2[:, INDEX.PHI.value], data_2[:, INDEX.PHI_Z2.value], label = f'$\\tau$ = {0.05}')
plt.plot(data_3[:, INDEX.PHI.value], data_3[:, INDEX.PHI_Z2.value], label = f'$\\tau$ = {0.1}')
plt.plot(data_4[:, INDEX.PHI.value], data_4[:, INDEX.PHI_Z2.value], label = f'$\\tau$ = {0.5}')

plt.yticks(
    [-np.pi, -np.pi/2, 0, np.pi/2, np.pi, (3*np.pi)/2, 2*np.pi, 5*np.pi/2, 3*np.pi], 
    ['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$', '$3\pi/2$', '$2\pi$', '$5\pi/2$', '$3\pi$']
)

plt.ylim(-np.pi/2, 5*np.pi/2)
plt.title(f'Optimized $\\phi_{{z2}}$')
plt.xlabel('Time')
plt.ylabel('RAD')
plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(data_0[0][:, INDEX.PHI.value], data_0[0][:, INDEX.PHI_Z3.value], label = f'$\\tau$ = {0}')
plt.plot(data_1[:, INDEX.PHI.value], data_1[:, INDEX.PHI_Z3.value], label = f'$\\tau$ = {0.005}')
plt.plot(data_2[:, INDEX.PHI.value], data_2[:, INDEX.PHI_Z3.value], label = f'$\\tau$ = {0.05}')
plt.plot(data_3[:, INDEX.PHI.value], data_3[:, INDEX.PHI_Z3.value], label = f'$\\tau$ = {0.1}')
plt.plot(data_4[:, INDEX.PHI.value], data_4[:, INDEX.PHI_Z3.value], label = f'$\\tau$ = {0.5}')

plt.yticks(
    [-np.pi, -np.pi/2, 0, np.pi/2, np.pi, (3*np.pi)/2, 2*np.pi, 5*np.pi/2, 3*np.pi], 
    ['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$', '$3\pi/2$', '$2\pi$', '$5\pi/2$', '$3\pi$']
)

plt.ylim(np.pi/2, 6*np.pi/2)
plt.title(f'Optimized $\\phi_{{z3}}$')
plt.xlabel('Time')
plt.ylabel('RAD')
plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(data_0[0][:, INDEX.PHI.value], data_0[0][:, INDEX.TAU_1.value], label = f'$\\tau$ = {0}')
plt.plot(data_1[:, INDEX.PHI.value], data_1[:, INDEX.TAU_1.value], label = f'$\\tau$ = {0.005}')
plt.plot(data_2[:, INDEX.PHI.value], data_2[:, INDEX.TAU_1.value], label = f'$\\tau$ = {0.05}')
plt.plot(data_3[:, INDEX.PHI.value], data_3[:, INDEX.TAU_1.value], label = f'$\\tau$ = {0.1}')
plt.plot(data_4[:, INDEX.PHI.value], data_4[:, INDEX.TAU_1.value], label = f'$\\tau$ = {0.5}')



plt.yticks(
    [-np.pi, -np.pi/2, 0, np.pi/2, np.pi, (3*np.pi)/2, 2*np.pi], 
    ['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$', '$3\pi/2$', '$2\pi$']
)
plt.ylim(0, np.pi/2)
plt.title(f'Optimized $\\tau_{1}$')
plt.xlabel('Time')
plt.ylabel('RAD')
plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(data_0[0][:, INDEX.PHI.value], data_0[0][:, INDEX.TAU_2.value], label = f'$\\tau$ = {0}')
plt.plot(data_1[:, INDEX.PHI.value], data_1[:, INDEX.TAU_2.value], label = f'$\\tau$ = {0.005}')
plt.plot(data_2[:, INDEX.PHI.value], data_2[:, INDEX.TAU_2.value], label = f'$\\tau$ = {0.05}')
plt.plot(data_3[:, INDEX.PHI.value], data_3[:, INDEX.TAU_2.value], label = f'$\\tau$ = {0.1}')
plt.plot(data_4[:, INDEX.PHI.value], data_4[:, INDEX.TAU_2.value], label = f'$\\tau$ = {0.5}')



plt.yticks(
    [-np.pi, -np.pi/2, 0, np.pi/2, np.pi, (3*np.pi)/2, 2*np.pi], 
    ['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$', '$3\pi/2$', '$2\pi$']
)
plt.ylim(0, np.pi)
plt.title(f'Optimized $\\tau_{2}$')
plt.xlabel('Time')
plt.ylabel('RAD')
plt.grid()
plt.legend()
plt.show()
