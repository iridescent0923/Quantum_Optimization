# %%
import matplotlib.pyplot as plt
from IPython.display import display, Latex
from matplotlib.ticker import MultipleLocator
import numpy as np  # Original numpy

from enum import Enum

# %%
class INDEX(Enum):
    PHI = 0
    CFI = 1
    
    THETA_X1 = 2
    THETA_X2 = 3
    
    PHI_Z1 = 4
    PHI_Z2 = 5
    PHI_Z3 = 6
    PHI_Z4 = 7
    
    TAU_L1 = 8
    TAU_L2 = 9
    
    TAU_R1 = 10
    TAU_R2 = 11

# %%
class DataPlotter:
    def __init__(self, data_in):
        self.data_in = data_in
        
    def plot_cfi(self, tau_dephase=0, gamma_ps=0):        
        plt.plot(
            self.data_in[0][:,INDEX.PHI.value], 
            self.data_in[0][:,INDEX.CFI.value], 
            label = f'$\\tau$ = {tau_dephase}')
        
        plt.title(f'CFI at $\gamma_{{ps}} = {gamma_ps}$')
        plt.xlabel('Time')
        plt.ylabel('CFI')
        plt.grid()
        plt.legend()
        # plt.show()
        
    def plot_theta_x1(self, tau_dephase=0, set_ylim=(0, 0)):
        plt.plot(
            self.data_in[0][:,INDEX.PHI.value], 
            self.data_in[0][:,INDEX.THETA_X1.value], 
            label = f'$\\tau$ = {tau_dephase}')
        
        self.plot_settings(
            title = f'Optimized $\\theta_{{x1}}$',
            ylim = set_ylim
        )

    def plot_theta_x2(self, tau_dephase=0, set_ylim=(0, 0)):
        plt.plot(
            self.data_in[0][:,INDEX.PHI.value], 
            self.data_in[0][:,INDEX.THETA_X2.value], 
            label = f'$\\tau$ = {tau_dephase}')
        
        self.plot_settings(
            title = f'Optimized $\\theta_{{x2}}$',
            ylim = set_ylim
        )
        
    def plot_phi_z1(self, tau_dephase=0, set_ylim=(0, 0)):
        plt.plot(
            self.data_in[0][:,INDEX.PHI.value], 
            self.data_in[0][:,INDEX.PHI_Z1.value], 
            label = f'$\\tau$ = {tau_dephase}')
        
        self.plot_settings(
                    title = f'Optimized $\\phi_{{z1}}$',
                    ylim = set_ylim
        )
        
    def plot_phi_z2(self, tau_dephase=0, set_ylim=(0, 0)):
        plt.plot(
            self.data_in[0][:,INDEX.PHI.value], 
            self.data_in[0][:,INDEX.PHI_Z2.value], 
            label = f'$\\tau$ = {tau_dephase}')
        
        self.plot_settings(
                    title = f'Optimized $\\phi_{{z2}}$',
                    ylim = set_ylim
        )
        
    def plot_phi_z3(self, tau_dephase=0, set_ylim=(0, 0)):
        plt.plot(
            self.data_in[0][:,INDEX.PHI.value], 
            self.data_in[0][:,INDEX.PHI_Z3.value], 
            label = f'$\\tau$ = {tau_dephase}')

        self.plot_settings(
                    title = f'Optimized $\\phi_{{z3}}$',
                    ylim = set_ylim
        )
        
    def plot_phi_z4(self, tau_dephase=0, set_ylim=(0, 0)):
        plt.plot(
            self.data_in[0][:,INDEX.PHI.value], 
            self.data_in[0][:,INDEX.PHI_Z4.value], 
            label = f'$\\tau$ = {tau_dephase}')

        self.plot_settings(
                    title = f'Optimized $\\phi_{{z4}}$',
                    ylim = set_ylim
        )
        
    def plot_tau_L1(self, tau_dephase=0, set_ylim=(0, 0)):
        plt.plot(
            self.data_in[0][:,INDEX.PHI.value], 
            self.data_in[0][:,INDEX.TAU_L1.value], 
            label = f'$\\tau$ = {tau_dephase}')
        
        self.plot_settings(
                    title = f'Optimized $\\tau_{{L1}}$',
                    ylim = set_ylim
        )
        
    def plot_tau_L2(self, tau_dephase=0, set_ylim=(0, 0)):
        plt.plot(
            self.data_in[0][:,INDEX.PHI.value], 
            self.data_in[0][:,INDEX.TAU_L2.value], 
            label = f'$\\tau$ = {tau_dephase}')

        self.plot_settings(
                    title = f'Optimized $\\tau_{{L2}}$',
                    ylim = set_ylim
        )
        
    def plot_tau_R1(self, tau_dephase=0, set_ylim=(0, 0)):
        plt.plot(
            self.data_in[0][:,INDEX.PHI.value], 
            self.data_in[0][:,INDEX.TAU_R1.value], 
            label = f'$\\tau$ = {tau_dephase}')

        self.plot_settings(
                    title = f'Optimized $\\tau_{{R1}}$',
                    ylim = set_ylim
        )
        
    def plot_tau_R2(self, tau_dephase=0, set_ylim=(0, 0)):
        plt.plot(
            self.data_in[0][:,INDEX.PHI.value], 
            self.data_in[0][:,INDEX.TAU_R2.value], 
            label = f'$\\tau$ = {tau_dephase}')

        self.plot_settings(
                    title = f'Optimized $\\tau_{{R2}}$',
                    ylim = set_ylim
        )
        
    def plot_settings(self, title, xlabel='Time', ylabel='Rad', ylim=(-2*np.pi, 2*np.pi)):
        plt.yticks(
            [-np.pi, -3*np.pi/4, -np.pi/2, -np.pi/4, 0, np.pi/4, np.pi/2, 3*np.pi/4, np.pi, (3*np.pi)/2, 2*np.pi, 5*np.pi/2], 
            ['$-\pi$', '$-3\pi/4$', '$-\pi/2$', '$-\pi/4$', '0', '$\pi/4$', '$\pi/2$', '$3\pi/4$', '$\pi$', '$3\pi/2$', '$2\pi$', '$5\pi/2$']
        )
        plt.ylim(ylim)
        plt.title(title)
        plt.xlabel(xlabel)
        plt.ylabel(ylabel)
        plt.grid()
        plt.legend()
        # plt.show()

# %%
data_files = {
    'data_0': 'result_[0]_new.npy',
    'data_0.005': 'result_[0.005]_auto_new.npy',
    'data_0.05': 'result_[0.05]_auto.npy',
    'data_0.1': 'result_[0.1]_auto.npy',
    'data_0.5': 'result_[0.5]_new.npy'
}

data = {}
for key, file_name in data_files.items():
    data[key] = np.load(file_name)

# %%
for key, dataset in data.items():
    print(key.split('_')[1])
# Out:
# 0
# 0.005
# 0.05
# 0.1
# 0.5

# %%
for key, dataset in data.items():
    plotter = DataPlotter(dataset)
    plotter.plot_cfi(tau_dephase=key.split('_')[1], gamma_ps=0.5)
    plt.legend()

# %%
for key, dataset in data.items():
    plotter = DataPlotter(dataset)
    plotter.plot_theta_x1(tau_dephase=key.split('_')[1], set_ylim=(0, 3))

# %%
data['data_0.1'][0][:, INDEX.TAU_R2.value]
# Out:
# array([0.0765788 , 0.07648435, 0.076377  , 0.07646491, 0.07638537,
#        0.07641643, 0.07640858, 0.07641595, 0.07640874, 0.07641075,
#        0.0764152 , 0.07641659, 0.07642297, 0.07639553, 0.07648398,
#        0.07637631, 0.07647868, 0.07635722, 0.07643271, 0.07639791,
#        0.07642461, 0.07640091, 0.07642382, 0.07639837, 0.07641551,
#        0.07640637, 0.0764536 , 0.0763768 , 0.07641296, 0.07641075,
#        0.07641734, 0.07636978, 0.07656641, 0.07640463, 0.07642182,
#        0.07637537, 0.07642841, 0.07640394, 0.07643033, 0.07642183,
#        0.07646466, 0.07642819, 0.07634901, 0.0764538 , 0.07631272,
#        0.07655511, 0.07636394, 0.07668568, 0.07599146, 0.07675184,
#        0.07625232, 0.07641788, 0.07656752, 0.0761046 , 0.07657506,
#        0.07616869, 0.07647768, 0.07636794, 0.07641359, 0.07641894,
#        0.0763192 , 0.07641853, 0.07639883, 0.07649435, 0.07628394,
#        0.07680625, 0.07601004, 0.07674244, 0.07637616, 0.07642495,
# ...

# %%
for key, dataset in data.items():
    plotter = DataPlotter(dataset)
    plotter.plot_theta_x2(tau_dephase=key.split('_')[1], set_ylim=(np.pi/8, 3*np.pi/8))

# %%
for key, dataset in data.items():
    plotter = DataPlotter(dataset)
    plotter.plot_phi_z1(tau_dephase=key.split('_')[1], set_ylim=(-np.pi/8, 5*np.pi/2))

# %%
for key, dataset in data.items():
    plotter = DataPlotter(dataset)
    plotter.plot_phi_z2(tau_dephase=key.split('_')[1], set_ylim=(0, 5*np.pi/2))

# %%
for key, dataset in data.items():
    plotter = DataPlotter(dataset)
    plotter.plot_phi_z3(tau_dephase=key.split('_')[1], set_ylim=(0, 5*np.pi/2))

# %%
for key, dataset in data.items():
    plotter = DataPlotter(dataset)
    plotter.plot_phi_z4(tau_dephase=key.split('_')[1], set_ylim=(0, 5*np.pi/2))

# %%
for key, dataset in data.items():
    plotter = DataPlotter(dataset)
    plotter.plot_tau_L1(tau_dephase=key.split('_')[1], set_ylim=(-0.1, np.pi/4))

# %%
for key, dataset in data.items():
    plotter = DataPlotter(dataset)
    plotter.plot_tau_L2(tau_dephase=key.split('_')[1], set_ylim=(-1.1*np.pi, np.pi/4))

# %%
for key, dataset in data.items():
    plotter = DataPlotter(dataset)
    plotter.plot_tau_R1(tau_dephase=key.split('_')[1], set_ylim=(np.pi/8, 1.5*np.pi/4))

# %%
for key, dataset in data.items():
    plotter = DataPlotter(dataset)
    plotter.plot_tau_R2(tau_dephase=key.split('_')[1], set_ylim=(-0.1, 3*np.pi/8))
