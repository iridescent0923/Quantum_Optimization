# %%
import matplotlib.pyplot as plt
from IPython.display import display, Latex
from matplotlib.ticker import MultipleLocator
import numpy as np  # Original numpy

import pandas as pd
from enum import Enum

# %%
class INDEX(Enum):
    PHI = 0
    CFI = 1
    
    THETA_X = 2
    
    PHI_Z1 = 3
    PHI_Z2 = 4
    PHI_Z3 = 5
    
    TAU_1 = 6
    TAU_2 = 7

# %%
# data_0 = pd.read_csv('result_0_new.csv').values # 1e-4
# data_0_PHI = np.arange(1e-2, 6.279899999999962, 1e-4)

data_0 = np.load('result_[0]_new.npy')
data_1 = np.load('result_0.005.npy')
data_2 = np.load('result_0.05.npy')
data_3 = np.load('result_0.1_N.npy')
data_4 = np.load('result_0.5.npy')

# %%
# plt.plot(data_0_PHI, data_0[:, 0], label = f'$\\tau$ = {0}')
plt.plot(data_0[0][:, INDEX.PHI.value], data_0[0][:, INDEX.CFI.value], label = f'$\\tau$ = {0}')
plt.plot(data_1[0][:, INDEX.PHI.value], data_1[0][:, INDEX.CFI.value], label = f'$\\tau$ = {0.005}')
plt.plot(data_2[0][:, INDEX.PHI.value], data_2[0][:, INDEX.CFI.value], label = f'$\\tau$ = {0.05}')
plt.plot(data_3[0][:, INDEX.PHI.value], data_3[0][:, INDEX.CFI.value], label = f'$\\tau$ = {0.1}')
plt.plot(data_4[0][:, INDEX.PHI.value], data_4[0][:, INDEX.CFI.value], label = f'$\\tau$ = {0.5}')
plt.title(f'CFI at $\gamma_{{ps}} = {0.8}$')
plt.xlabel('Time')
plt.ylabel('CFI')
plt.grid()
plt.legend()
plt.show()

# %%
# plt.plot(data_0_PHI, data_0[:, 1], label = f'$\\tau$ = {0}')
plt.plot(data_0[0][:, INDEX.PHI.value], data_0[0][:, INDEX.THETA_X.value], label = f'$\\tau$ = {0}')
plt.plot(data_1[0][:, INDEX.PHI.value], data_1[0][:, INDEX.THETA_X.value], label = f'$\\tau$ = {0.005}')
plt.plot(data_2[0][:, INDEX.PHI.value], data_2[0][:, INDEX.THETA_X.value], label = f'$\\tau$ = {0.05}')
plt.plot(data_3[0][:, INDEX.PHI.value], data_3[0][:, INDEX.THETA_X.value], label = f'$\\tau$ = {0.1}')
plt.plot(data_4[0][:, INDEX.PHI.value], data_4[0][:, INDEX.THETA_X.value], label = f'$\\tau$ = {0.5}')

plt.yticks(
    [-np.pi, -np.pi/2, 0, np.pi/2, np.pi, (3*np.pi)/2, 2*np.pi], 
    ['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$', '$3\pi/2$', '$2\pi$']
)
plt.ylim(-np.pi/2, 2*np.pi/2)
plt.title(f'Optimized $\\theta_{{x}}$')
plt.xlabel('Time')
plt.ylabel('RAD')
plt.grid()
plt.legend()
plt.show()

# %%
# plt.plot(data_0_PHI, data_0[:, 2], label = f'$\\tau$ = {0}')
plt.plot(data_0[0][:, INDEX.PHI.value], data_0[0][:, INDEX.THETA_X.value], label = f'$\\tau$ = {0}')
plt.plot(data_1[0][:, INDEX.PHI.value], data_1[0][:, INDEX.PHI_Z1.value], label = f'$\\tau$ = {0.005}')
plt.plot(data_2[0][:, INDEX.PHI.value], data_2[0][:, INDEX.PHI_Z1.value], label = f'$\\tau$ = {0.05}')
plt.plot(data_3[0][:, INDEX.PHI.value], data_3[0][:, INDEX.PHI_Z1.value], label = f'$\\tau$ = {0.1}')
plt.plot(data_4[0][:, INDEX.PHI.value], data_4[0][:, INDEX.PHI_Z1.value], label = f'$\\tau$ = {0.5}')

plt.yticks(
    [-np.pi, -np.pi/2, 0, np.pi/2, np.pi, (3*np.pi)/2, 2*np.pi, 5*np.pi/2, 3*np.pi], 
    ['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$', '$3\pi/2$', '$2\pi$', '$5\pi/2$', '$3\pi$']
)

plt.ylim(0, 6*np.pi/2)
plt.title(f'Optimized $\\phi_{{z1}}$')
plt.xlabel('Time')
plt.ylabel('RAD')
plt.grid()
plt.legend()
plt.show()

# %%
# plt.plot(data_0_PHI, data_0[:, 3], label = f'$\\tau$ = {0}')
plt.plot(data_0[0][:, INDEX.PHI.value], data_0[0][:, INDEX.THETA_X.value], label = f'$\\tau$ = {0}')
plt.plot(data_1[0][:, INDEX.PHI.value], data_1[0][:, INDEX.PHI_Z2.value], label = f'$\\tau$ = {0.005}')
plt.plot(data_2[0][:, INDEX.PHI.value], data_2[0][:, INDEX.PHI_Z2.value], label = f'$\\tau$ = {0.05}')
plt.plot(data_3[0][:, INDEX.PHI.value], data_3[0][:, INDEX.PHI_Z2.value], label = f'$\\tau$ = {0.1}')
plt.plot(data_4[0][:, INDEX.PHI.value], data_4[0][:, INDEX.PHI_Z2.value], label = f'$\\tau$ = {0.5}')

plt.yticks(
    [-np.pi, -np.pi/2, 0, np.pi/2, np.pi, (3*np.pi)/2, 2*np.pi, 5*np.pi/2, 3*np.pi], 
    ['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$', '$3\pi/2$', '$2\pi$', '$5\pi/2$', '$3\pi$']
)

plt.ylim(-np.pi/2, 7*np.pi/2)
plt.title(f'Optimized $\\phi_{{z2}}$')
plt.xlabel('Time')
plt.ylabel('RAD')
plt.grid()
plt.legend()
plt.show()

# %%
# plt.plot(data_0_PHI, data_0[:, 4], label = f'$\\tau$ = {0}')
plt.plot(data_0[0][:, INDEX.PHI.value], data_0[0][:, INDEX.THETA_X.value], label = f'$\\tau$ = {0}')
plt.plot(data_1[0][:, INDEX.PHI.value], data_1[0][:, INDEX.PHI_Z3.value], label = f'$\\tau$ = {0.005}')
plt.plot(data_2[0][:, INDEX.PHI.value], data_2[0][:, INDEX.PHI_Z3.value], label = f'$\\tau$ = {0.05}')
plt.plot(data_3[0][:, INDEX.PHI.value], data_3[0][:, INDEX.PHI_Z3.value], label = f'$\\tau$ = {0.1}')
plt.plot(data_4[0][:, INDEX.PHI.value], data_4[0][:, INDEX.PHI_Z3.value], label = f'$\\tau$ = {0.5}')

plt.yticks(
    [-np.pi, -np.pi/2, 0, np.pi/2, np.pi, (3*np.pi)/2, 2*np.pi, 5*np.pi/2, 3*np.pi], 
    ['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$', '$3\pi/2$', '$2\pi$', '$5\pi/2$', '$3\pi$']
)

plt.ylim(0, 6*np.pi/2)
plt.title(f'Optimized $\\phi_{{z3}}$')
plt.xlabel('Time')
plt.ylabel('RAD')
plt.grid()
plt.legend()
plt.show()

# %%
# plt.plot(data_0_PHI, data_0[:, 5], label = f'$\\tau$ = {0}')
plt.plot(data_0[0][:, INDEX.PHI.value], data_0[0][:, INDEX.THETA_X.value], label = f'$\\tau$ = {0}')
plt.plot(data_1[0][:, INDEX.PHI.value], data_1[0][:, INDEX.TAU_1.value], label = f'$\\tau$ = {0.005}')
plt.plot(data_2[0][:, INDEX.PHI.value], data_2[0][:, INDEX.TAU_1.value], label = f'$\\tau$ = {0.05}')
plt.plot(data_3[0][:, INDEX.PHI.value], data_3[0][:, INDEX.TAU_1.value], label = f'$\\tau$ = {0.1}')
plt.plot(data_4[0][:, INDEX.PHI.value], data_4[0][:, INDEX.TAU_1.value], label = f'$\\tau$ = {0.5}')



plt.yticks(
    [-np.pi, -np.pi/2, 0, np.pi/2, np.pi, (3*np.pi)/2, 2*np.pi], 
    ['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$', '$3\pi/2$', '$2\pi$']
)
plt.ylim(-np.pi/2, np.pi/2)
plt.title(f'Optimized $\\tau_{1}$')
plt.xlabel('Time')
plt.ylabel('RAD')
plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(data_0[0][:, INDEX.PHI.value], data_0[0][:, INDEX.THETA_X.value], label = f'$\\tau$ = {0}')
plt.plot(data_1[0][:, INDEX.PHI.value], data_1[0][:, INDEX.TAU_2.value], label = f'$\\tau$ = {0.005}')
plt.plot(data_2[0][:, INDEX.PHI.value], data_2[0][:, INDEX.TAU_2.value], label = f'$\\tau$ = {0.05}')
plt.plot(data_3[0][:, INDEX.PHI.value], data_3[0][:, INDEX.TAU_2.value], label = f'$\\tau$ = {0.1}')
plt.plot(data_4[0][:, INDEX.PHI.value], data_4[0][:, INDEX.TAU_2.value], label = f'$\\tau$ = {0.5}')



plt.yticks(
    [-np.pi, -np.pi/2, 0, np.pi/2, np.pi, (3*np.pi)/2, 2*np.pi], 
    ['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$', '$3\pi/2$', '$2\pi$']
)
plt.ylim(-np.pi/2, np.pi/2)
plt.title(f'Optimized $\\tau_{2}$')
plt.xlabel('Time')
plt.ylabel('RAD')
plt.grid()
plt.legend()
plt.show()
