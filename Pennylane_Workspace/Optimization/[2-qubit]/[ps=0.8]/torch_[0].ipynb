# %%
# ==============================
# Standard Library Imports
# ==============================
from enum import Enum
import random

# ==============================
# Third-party Library Imports
# ==============================
import matplotlib.pyplot as plt
from IPython.display import display, Latex
from matplotlib.ticker import MultipleLocator
import numpy as np  # Original numpy
import pennylane as qml
import torch 

# ==============================
# User defined 
# ==============================
import plot_data as pt
import torch_optimizer as tr_opt

# ==============================
# Setup for Quantum Computations
# ==============================

# PennyLane settings
dev = qml.device('default.mixed', wires=2)

# Define Hamiltonian for quantum computations
H = qml.Hamiltonian(
    coeffs=[-0.5], 
    observables=[
        qml.PauliZ(0) @ qml.PauliZ(1) 
    ]
)

H_1 = qml.Hamiltonian(
    coeffs=[-0.5, -0.5], 
    observables=[
        qml.PauliZ(0), qml.PauliZ(1)
    ]
)

# %% [markdown]
# ## New Hamiltonian
#
# #### Entangler Hamiltonian
#
# $$
# H =
# -0.5 \cdot(
#  \, Z_0 \otimes Z_1 \otimes I_{2} \otimes I_3
#  + \, Z_{0} \otimes I_1 \otimes Z_{2} \otimes I_3
#  + \, I_{0} \otimes Z_1 \otimes Z_{2} \otimes I_{3} \\
#  + \, I_{0} \otimes Z_1 \otimes I_{2} \otimes Z_3
#  + \, I_{0} \otimes I_1 \otimes Z_{2} \otimes Z_3
# )
# $$
#
#
# $$
# where,
# Z = \begin{pmatrix}
# 1 & 0 \\
# 0 & -1
# \end{pmatrix}
# $$

# %% [markdown]
# #### Entangler Hamiltonian_2
#
# $$
# H =
# -0.5 \cdot (
#  \, Z_0 \otimes Z_1 \otimes I_{2} \otimes I_3
#  + \, Z_{0} \otimes I_1 \otimes Z_{2} \otimes I_3
#  + \, Z_{0} \otimes I_1 \otimes I_{2} \otimes Z_3\\
#  + \, I_{0} \otimes Z_1 \otimes Z_{2} \otimes I_{3}
#  + \, I_{0} \otimes Z_1 \otimes I_{2} \otimes Z_3
#  + \, I_{0} \otimes I_1 \otimes Z_{2} \otimes Z_3
# )
# $$
#
#
# $$
# where,
# Z = \begin{pmatrix}
# 1 & 0 \\
# 0 & -1
# \end{pmatrix}
# $$

# %% [markdown]
# #### Phase Accumulator Hamiltonian
#
#
# $$
# H_{1} = -0.5 \cdot (
#     Z_0 + Z_1 + Z_2 + Z_3
# )
# $$
#
#
#
# $$
#
# $$
#
#
# $$
# where,
# Z = \begin{pmatrix} 1 & 0 \\ 0 & -1 \end{pmatrix}
# $$

# %%
# Global Parameters
Tau_global = torch.tensor(0, dtype=torch.float, requires_grad=False)   # Dephase tau
Gamma_ps_global = torch.tensor(0, dtype=torch.float, requires_grad=False)
Paras_global = torch.tensor([0, 0, 0, 0, 0], dtype=torch.float, requires_grad=True)
Phi_global = torch.tensor(0, dtype=torch.float, requires_grad=True)

def Dephase_factor(tau):
    """ 
    Calculate the dephasing factor for a given dephasing time tau.

    Args:
        tau (torch.Tensor): Dephasing time.

    Returns:
        torch.Tensor: Dephasing factor.
    """  
    return 1 - torch.exp(-2 * tau)

# %% [markdown]
# $$
# Let, e^{-t/T_2} = e^{-\tau} \\[1em]
#
# \frac{1}{2}
#
# \begin{bmatrix}
#
# 1 & e^{(i\phi - \tau)} \\
# e^{(-i\phi - \tau)} & 1
#
# \end{bmatrix}
#
# =
#
# \frac{1}{2}
#
# \begin{bmatrix}
#
# 1 & e^{i\phi} \sqrt{1 - \gamma} \\
# e^{-i\phi} \sqrt{1 - \gamma} & 1
#
# \end{bmatrix}
# $$
#
# $$
# \\[1em]
# Then,
# \quad \gamma =
# 1 - e^{-2 \tau}
# $$
#
# $$
# e^{-\tau} = \sqrt{1 - \gamma}
# $$

# %%
class INDEX(Enum):
    THETA_X = 0
    
    PHI_Z1 = 1
    PHI_Z2 = 2
    
    TAU_1 = 3
    TAU_2 = 4


@qml.qnode(dev, interface='torch', diff_method='backprop')
def circuit(phi):
    global Paras_global, Tau_global
    theta_x = Paras_global[0]
        
    phi_z = Paras_global[1]

    tau_1 = Paras_global[2]
    tau_2 = Paras_global[3]
    
    gamma_dephase = Dephase_factor(Tau_global)
    
    # Stage_1: RY for pi/2
    qml.RY(torch.pi/2, wires=0)
    qml.RY(torch.pi/2, wires=1)
    
    # Stage_2: Entangler  
    qml.ApproxTimeEvolution(H, tau_1, 1)
    qml.PhaseDamping(gamma_dephase, wires = 0)
    qml.PhaseDamping(gamma_dephase, wires = 1)    
    
    qml.RX(theta_x, wires = 0)    
    qml.RX(theta_x, wires = 1)       

    qml.RY(-torch.pi/2, wires = 0)    
    qml.RY(-torch.pi/2, wires = 1)     

    qml.ApproxTimeEvolution(H, tau_2, 1)
    qml.PhaseDamping(gamma_dephase, wires = 0)
    qml.PhaseDamping(gamma_dephase, wires = 1) 
    
    qml.RY(torch.pi/2, wires = 0)    
    qml.RY(torch.pi/2, wires = 1) 

    # Stage_4: Accumulator
    qml.ApproxTimeEvolution(H_1, phi, 1)
    qml.PhaseDamping(gamma_dephase, wires = 0)
    qml.PhaseDamping(gamma_dephase, wires = 1) 
    
    qml.RZ(phi_z, wires=0)
    qml.RZ(phi_z, wires=1)
    
    qml.RX(torch.pi/(2), wires=0)
    qml.RX(torch.pi/(2), wires=1)
    
    # return qml.state()
    return qml.density_matrix(wires = [0, 1])

fig, ax = qml.draw_mpl(circuit)(np.pi)

# %%
@qml.qnode(dev, interface = 'torch', diff_method = 'backprop')
def Post_selection(phi):

    global Paras_global, Gamma_ps_global
    get_density_matrix = circuit(phi)
        
    # Kraus operator for 2*2 matrix
    K = torch.tensor([
        [torch.sqrt(1 - Gamma_ps_global), 0], 
        [0, 1]
    ], dtype=torch.complex128)
    
    I_2 = torch.eye(2)  # 2*2
    
    num_1 = torch.kron(K, I_2) @ get_density_matrix @ torch.kron(K, I_2).conj().T
    num_2 = torch.kron(I_2, K) @ get_density_matrix @ torch.kron(I_2, K).conj().T
    
    den_1 = 2 * torch.trace(num_1)
    den_2 = 2 * torch.trace(num_2)
    
    rho_1 = num_1 / den_1
    rho_2 = num_2 / den_2
    
    rho_ps = rho_1 + rho_2
    
    qml.QubitDensityMatrix(rho_ps, wires = [0, 1])
    
    return qml.density_matrix(wires = [0, 1])

# %%
# @qml.qnode(dev, interface = 'torch', diff_method = 'backprop')
# def Post_selection(phi):

#     global Paras_global, Gamma_ps_global
#     get_density_matrix = circuit(phi)
        
#     # Kraus operator for 2*2 matrix
#     K = torch.tensor([
#         [torch.sqrt(1 - Gamma_ps_global), 0], 
#         [0, 1]
#     ], dtype=torch.complex128)
    
#     Numerator = torch.kron(K, K) @ get_density_matrix @ torch.kron(K, K).conj().T
#     Denominator = torch.trace(Numerator)
    
#     rho_ps = Numerator / Denominator
    
#     qml.QubitDensityMatrix(rho_ps, wires = [0, 1])
    
#     return qml.density_matrix(wires = [0, 1])

# %% [markdown]
# $$
# K =  \begin{bmatrix}
# \sqrt{1-\gamma_{ps}} & 0 \\
# 0 & 1
# \end{bmatrix}
# $$
#
#
# $$
# \rho_{ps} =
# \frac
# {(K \otimes I) \rho (K \otimes I)^{\dagger}}
# {2Tr[(K \otimes I) \rho (K \otimes I)^{\dagger}]}
#
# +
#
# \frac
# {(I \otimes K) \rho (I \otimes K)^{\dagger}}
# {2Tr[(I \otimes K) \rho (I \otimes K)^{\dagger}]}
# $$

# %%
def set_circuit(desired_tau_dephase, desired_gamma_post_selection):
    """
    Set the global dephasing rate and post-selection rate for the circuit.

    Args:
        desired_tau_dephase (float): Desired dephasing rate tau.
        desired_gamma_post_selection (float): Desired post-selection rate gamma.
    """
    global Tau_global, Gamma_ps_global 
    
    Tau_global = torch.tensor(desired_tau_dephase)
    Gamma_ps_global = torch.tensor([desired_gamma_post_selection])

# %%
def cost_function(paras):
    """ 
    Compute the cost using classical Fisher information for the given parameters.

    Args:
        paras (torch.Tensor): Parameters for quantum gates.

    Returns:
        torch.Tensor: Computed cost.
    """
    global Paras_global, Phi_global
    Paras_global = paras

    CFI = qml.qinfo.classical_fisher(Post_selection)(Phi_global)
    
    return -CFI

# %%
def sweep_cfi(sweep_range, initial_parameters):
    Phi = torch.arange(sweep_range[0], sweep_range[1], sweep_range[2], dtype=torch.float32)
    Data = torch.zeros((len(Phi), 2))
    Data[:,0] = Phi
    
    global Phi_global
    params_tensor = initial_parameters.clone().requires_grad_(True)
    
    for phi_idx in range(len(Phi)):
        Phi_global = Phi[phi_idx].clone().requires_grad_(True)
        
        Data[phi_idx, 1] = -cost_function(params_tensor)
        
    return Data

# %%
def sweep_by_tau(sweep_range, init_par, tau_dephase, gamma_post_selection):
    for tau_idx, tau_current in enumerate(tau_dephase):
        set_circuit(tau_current, gamma_post_selection)
        
        temp = sweep_cfi(sweep_range, init_par).detach().numpy()
        
        if tau_idx == 0:
            Data = np.zeros((len(tau_dephase), len(temp[:,0]), len(temp[0,:])))
            Data[tau_idx][:, :] = temp
        else:
            Data[tau_idx][:, :] = temp
        
    return Data

# %%
import time

def torch_optimization(sweep_range, initial_parameters, method):
    """ 
    Perform optimization using specified optimizer over a range of phi values.

    Args:
        sweep_range (list): Range of phi values for optimization.
        initial_parameters (torch.Tensor): Initial parameters for optimization.
        method (str): Optimization method ('LBFGS' or 'Adam').

    Returns:
        torch.Tensor: Data tensor containing optimization results.
    """
    Phi = torch.arange(sweep_range[0], sweep_range[1], sweep_range[2], dtype=torch.float32)
    Data = torch.zeros((len(Phi), len(initial_parameters) + 2))
    Data[:,0] = Phi
    
    global Phi_global
    params_tensor = initial_parameters.clone().requires_grad_(True)
    
    opt = tr_opt.select_optimizer(method, params_tensor)
    
    def closure():
        opt.zero_grad()
        loss = cost_function(params_tensor)
        loss.backward()
        return loss
       
    steps = 15
    f_logs = [cost_function(params_tensor).item()]
    ftol = 1e-10
        
    start_time = time.time()
    del_accu = 0
    # Begin optimization
    for phi_idx in range(len(Phi)):
        Phi_global = Phi[phi_idx].clone().requires_grad_(True)

        for i in range(steps):
            opt.step(closure)

            fval = cost_function(opt.param_groups[0]['params'][0]).item()
            f_logs.append(fval)
            if np.abs((fval-f_logs[-2])/fval) < ftol:
                break
            
        elapsed_time = time.time() - start_time
        estimated_total_time = (elapsed_time / (phi_idx + 1)) * len(Phi)
        remaining_time = estimated_total_time - elapsed_time
        
        formatted_x = [f"{x:.8f}" for x in opt.param_groups[0]['params'][0].detach().numpy()]
        
        del_CFI = (Data[phi_idx-1, 1]) + fval if phi_idx > 0 else 0
        del_accu += del_CFI
        print(
            "CFI =", f"{-fval:.5f}", 
            "Paras =", formatted_x, 
            f"[eta : {remaining_time / 60:.2f}_min,",
            f"iter_left : {len(Phi) - phi_idx},", 
            f"del_CFI : {del_CFI:.4f}]",
            f"del_accumulated : {del_accu:.4f}"
        )

        Data[phi_idx, 1] = -fval
        Data[phi_idx, 2:] = opt.param_groups[0]['params'][0]        
        
    return Data

# %%
def optimization_by_tau(sweep_range, init_par, tau_dephase, gamma_post_selection, method):
    """ 
    Iterate over different values of tau_dephase and gamma_post_selection for optimization.

    Args:
        sweep_range (list): Range of phi values for optimization.
        init_par (torch.Tensor): Initial parameters for optimization.
        tau_dephase (list): List of dephasing rates tau to iterate over.
        gamma_post_selection (float): Post-selection rate gamma.
        method (str): Optimization method.

    Returns:
        np.ndarray: Numpy array with optimization results for each tau.
    """
    for tau_idx, tau_current in enumerate(tau_dephase):
        set_circuit(tau_current, gamma_post_selection)
        
        temp = torch_optimization(sweep_range, init_par, method).detach().cpu().numpy()
        if tau_idx == 0:
            Data = np.zeros((len(tau_dephase), len(temp[:,0]), len(temp[0,:])))
            Data[tau_idx][:, :] = temp
        else:
            Data[tau_idx][:, :] = temp
            
    return Data

# %%
import time
sweep_range = torch.tensor(
    [1e-2, 2*torch.pi, 1e-2], 
    dtype=torch.float, requires_grad=False
)

init_par = torch.tensor([
    # theta_x
    torch.pi/4, 
    
    # phi_z
    torch.pi/4, 
    
    # tau_1:2
    torch.pi/4, torch.pi/4,
    ], dtype=torch.float)

tau_dephase = 0,
gamma_ps = 0

start_time = time.time()
res = optimization_by_tau(sweep_range, init_par, tau_dephase, gamma_ps, 'LBFGS')
end_time = time.time()

running_time = (end_time - start_time) / 60
# Out:
# CFI = 4.00000 Paras = ['0.78539842', '0.78539789', '-1.57121885', '0.78539819'] [eta : 12.89_min, iter_left : 628, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539842', '0.78539789', '-1.57121885', '0.78539819'] [eta : 9.33_min, iter_left : 627, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539842', '0.78539789', '-1.57121885', '0.78539819'] [eta : 7.98_min, iter_left : 626, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539884', '0.78539777', '-1.57121456', '0.78539819'] [eta : 8.64_min, iter_left : 625, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539884', '0.78539777', '-1.57121456', '0.78539819'] [eta : 8.17_min, iter_left : 624, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539920', '0.78539765', '-1.57121027', '0.78539819'] [eta : 8.57_min, iter_left : 623, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539985', '0.78539741', '-1.57120180', '0.78539819'] [eta : 9.85_min, iter_left : 622, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539985', '0.78539741', '-1.57120180', '0.78539819'] [eta : 9.34_min, iter_left : 621, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539997', '0.78539735', '-1.57119977', '0.78539819'] [eta : 9.20_min, iter_left : 620, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78540021', '0.78539723', '-1.57119572', '0.78539819'] [eta : 9.46_min, iter_left : 619, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78540021', '0.78539723', '-1.57119572', '0.78539819'] [eta : 9.11_min, iter_left : 618, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78540021', '0.78539723', '-1.57119572', '0.78539819'] [eta : 8.83_min, iter_left : 617, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78540021', '0.78539723', '-1.57119572', '0.78539819'] [eta : 8.55_min, iter_left : 616, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78540033', '0.78539717', '-1.57119370', '0.78539819'] [eta : 8.48_min, iter_left : 615, del_CFI : -0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78540045', '0.78539711', '-1.57119167', '0.78539819'] [eta : 8.49_min, iter_left : 614, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78540069', '0.78539687', '-1.57118368', '0.78539819'] [eta : 8.81_min, iter_left : 613, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78540069', '0.78539687', '-1.57118368', '0.78539819'] [eta : 8.63_min, iter_left : 612, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78540075', '0.78539681', '-1.57118177', '0.78539819'] [eta : 8.61_min, iter_left : 611, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78540093', '0.78539658', '-1.57117414', '0.78539819'] [eta : 8.81_min, iter_left : 610, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78540093', '0.78539652', '-1.57117224', '0.78539819'] [eta : 8.80_min, iter_left : 609, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78540093', '0.78539652', '-1.57117224', '0.78539819'] [eta : 8.62_min, iter_left : 608, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78540093', '0.78539640', '-1.57116842', '0.78539819'] [eta : 8.67_min, iter_left : 607, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78540093', '0.78539622', '-1.57116270', '0.78539819'] [eta : 8.80_min, iter_left : 606, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78540093', '0.78539598', '-1.57115543', '0.78539819'] [eta : 8.94_min, iter_left : 605, del_CFI : -0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78540093', '0.78539580', '-1.57115006', '0.78539819'] [eta : 8.99_min, iter_left : 604, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78540093', '0.78539580', '-1.57115006', '0.78539819'] [eta : 8.88_min, iter_left : 603, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78540081', '0.78539562', '-1.57114470', '0.78539819'] [eta : 8.92_min, iter_left : 602, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78540063', '0.78539544', '-1.57113934', '0.78539819'] [eta : 8.93_min, iter_left : 601, del_CFI : -0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78540057', '0.78539538', '-1.57113588', '0.78539819'] [eta : 8.85_min, iter_left : 600, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78540039', '0.78539521', '-1.57113087', '0.78539819'] [eta : 8.86_min, iter_left : 599, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78540039', '0.78539521', '-1.57113087', '0.78539819'] [eta : 8.73_min, iter_left : 598, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78540027', '0.78539509', '-1.57112753', '0.78539819'] [eta : 8.70_min, iter_left : 597, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78540015', '0.78539503', '-1.57112420', '0.78539819'] [eta : 8.69_min, iter_left : 596, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78540009', '0.78539497', '-1.57112253', '0.78539819'] [eta : 8.63_min, iter_left : 595, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78540009', '0.78539497', '-1.57112253', '0.78539819'] [eta : 8.49_min, iter_left : 594, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78540003', '0.78539497', '-1.57112086', '0.78539819'] [eta : 8.45_min, iter_left : 593, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539991', '0.78539491', '-1.57111752', '0.78539819'] [eta : 8.41_min, iter_left : 592, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539968', '0.78539491', '-1.57111108', '0.78539819'] [eta : 8.48_min, iter_left : 591, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539962', '0.78539491', '-1.57110798', '0.78539819'] [eta : 8.45_min, iter_left : 590, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539950', '0.78539491', '-1.57110488', '0.78539819'] [eta : 8.41_min, iter_left : 589, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539950', '0.78539491', '-1.57110488', '0.78539819'] [eta : 8.29_min, iter_left : 588, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539938', '0.78539491', '-1.57109559', '0.78539819'] [eta : 8.40_min, iter_left : 587, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539926', '0.78539491', '-1.57108521', '0.78539819'] [eta : 8.54_min, iter_left : 586, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539920', '0.78539491', '-1.57108235', '0.78539819'] [eta : 8.51_min, iter_left : 585, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539920', '0.78539491', '-1.57108235', '0.78539819'] [eta : 8.40_min, iter_left : 584, del_CFI : -0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78539908', '0.78539491', '-1.57107949', '0.78539819'] [eta : 8.34_min, iter_left : 583, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539902', '0.78539491', '-1.57107663', '0.78539819'] [eta : 8.28_min, iter_left : 582, del_CFI : -0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78539902', '0.78539491', '-1.57107663', '0.78539819'] [eta : 8.18_min, iter_left : 581, del_CFI : 0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78539902', '0.78539491', '-1.57107663', '0.78539819'] [eta : 8.08_min, iter_left : 580, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539884', '0.78539491', '-1.57107234', '0.78539819'] [eta : 8.08_min, iter_left : 579, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539878', '0.78539491', '-1.57106960', '0.78539819'] [eta : 8.10_min, iter_left : 578, del_CFI : -0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78539872', '0.78539491', '-1.57106829', '0.78539819'] [eta : 8.06_min, iter_left : 577, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539872', '0.78539491', '-1.57106423', '0.78539819'] [eta : 8.10_min, iter_left : 576, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539866', '0.78539491', '-1.57105637', '0.78539819'] [eta : 8.23_min, iter_left : 575, del_CFI : -0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78539860', '0.78539491', '-1.57105374', '0.78539819'] [eta : 8.20_min, iter_left : 574, del_CFI : 0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78539854', '0.78539491', '-1.57104981', '0.78539819'] [eta : 8.20_min, iter_left : 573, del_CFI : 0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78539854', '0.78539491', '-1.57104981', '0.78539819'] [eta : 8.12_min, iter_left : 572, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539848', '0.78539467', '-1.57103860', '0.78539819'] [eta : 8.26_min, iter_left : 571, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539848', '0.78539467', '-1.57103860', '0.78539819'] [eta : 8.18_min, iter_left : 570, del_CFI : -0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78539842', '0.78539461', '-1.57102668', '0.78539819'] [eta : 8.41_min, iter_left : 569, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539842', '0.78539461', '-1.57102430', '0.78539819'] [eta : 8.38_min, iter_left : 568, del_CFI : -0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78539842', '0.78539461', '-1.57102430', '0.78539819'] [eta : 8.31_min, iter_left : 567, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539836', '0.78539461', '-1.57102072', '0.78539819'] [eta : 8.30_min, iter_left : 566, del_CFI : -0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78539836', '0.78539461', '-1.57102072', '0.78539819'] [eta : 8.22_min, iter_left : 565, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539830', '0.78539461', '-1.57101858', '0.78539819'] [eta : 8.19_min, iter_left : 564, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539830', '0.78539461', '-1.57101858', '0.78539819'] [eta : 8.11_min, iter_left : 563, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539830', '0.78539461', '-1.57101858', '0.78539819'] [eta : 8.02_min, iter_left : 562, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539830', '0.78539461', '-1.57101858', '0.78539819'] [eta : 7.95_min, iter_left : 561, del_CFI : -0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78539830', '0.78539461', '-1.57101858', '0.78539819'] [eta : 7.91_min, iter_left : 560, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539807', '0.78539455', '-1.57101750', '0.78539819'] [eta : 7.87_min, iter_left : 559, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539848', '0.78539455', '-1.57101512', '0.78539819'] [eta : 7.83_min, iter_left : 558, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539848', '0.78539455', '-1.57100320', '0.78539819'] [eta : 7.95_min, iter_left : 557, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539848', '0.78539455', '-1.57099569', '0.78539819'] [eta : 8.13_min, iter_left : 556, del_CFI : -0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78539848', '0.78539455', '-1.57098901', '0.78539819'] [eta : 8.15_min, iter_left : 555, del_CFI : 0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78539848', '0.78539455', '-1.57098806', '0.78539819'] [eta : 8.12_min, iter_left : 554, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539848', '0.78539455', '-1.57098603', '0.78539819'] [eta : 8.12_min, iter_left : 553, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539848', '0.78539455', '-1.57098603', '0.78539819'] [eta : 8.05_min, iter_left : 552, del_CFI : -0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78539819', '0.78539455', '-1.57098269', '0.78539819'] [eta : 8.04_min, iter_left : 551, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539819', '0.78539455', '-1.57097697', '0.78539819'] [eta : 8.07_min, iter_left : 550, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539819', '0.78539455', '-1.57097697', '0.78539819'] [eta : 8.02_min, iter_left : 549, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539819', '0.78539455', '-1.57097697', '0.78539819'] [eta : 7.97_min, iter_left : 548, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539819', '0.78539455', '-1.57097697', '0.78539819'] [eta : 7.91_min, iter_left : 547, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539819', '0.78539455', '-1.57097697', '0.78539819'] [eta : 7.86_min, iter_left : 546, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539819', '0.78539455', '-1.57097697', '0.78539819'] [eta : 7.81_min, iter_left : 545, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539819', '0.78539455', '-1.57097697', '0.78539819'] [eta : 7.76_min, iter_left : 544, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539819', '0.78539455', '-1.57097697', '0.78539819'] [eta : 7.71_min, iter_left : 543, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539819', '0.78539455', '-1.57097697', '0.78539819'] [eta : 7.68_min, iter_left : 542, del_CFI : -0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78539819', '0.78539455', '-1.57097697', '0.78539819'] [eta : 7.63_min, iter_left : 541, del_CFI : 0.0000] del_accumulated : 0.0000

# %%
np.save(f"result_[{tau_dephase[0]}]_{running_time:.2f}", res)

# %%
len(res[0][0, :])
# Out:
# 7

# %%
plt.plot(res[0][:,0], res[0][:,1], label = f'$\\tau$ = {tau_dephase}')
plt.title(f'CFI at $\gamma_{{ps}} = {gamma_ps}$')
plt.xlabel('Time')
plt.ylabel('CFI')
plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(res[0][:,0], res[0][:,INDEX.THETA_X.value + 2], label = f'$\\tau$ = {tau_dephase}')
            
plt.yticks(
    [-np.pi, -np.pi/2, 0, np.pi/2, np.pi, (3*np.pi)/2, 2*np.pi], 
    ['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$', '$3\pi/2$', '$2\pi$']
)
# plt.ylim(-np.pi/2, np.pi/2)
plt.title(f'Optimized $\\theta_{{x}}$')
plt.xlabel('Time')
plt.ylabel('RAD')
plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(res[0][:,0], res[0][:,INDEX.PHI_Z1.value + 2], label = f'$\\tau$ = {tau_dephase}')
            
plt.yticks(
    [-np.pi, -np.pi/2, 0, np.pi/2, np.pi, (3*np.pi)/2, 2*np.pi], 
    ['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$', '$3\pi/2$', '$2\pi$']
)
# plt.ylim(-np.pi/2, np.pi/2)
plt.title(f'Optimized $\\phi_{{z1}}$')
plt.xlabel('Time')
plt.ylabel('RAD')
plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(res[0][:,0], res[0][:,INDEX.PHI_Z2.value + 2], label = f'$\\tau$ = {tau_dephase}')
            
plt.yticks(
    [-np.pi, -np.pi/2, 0, np.pi/2, np.pi, (3*np.pi)/2, 2*np.pi], 
    ['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$', '$3\pi/2$', '$2\pi$']
)
# plt.ylim(-np.pi/2, np.pi/2)
plt.title(f'Optimized $\\phi_{{z2}}$')
plt.xlabel('Time')
plt.ylabel('RAD')
plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(res[0][:,0], res[0][:,INDEX.TAU_1.value + 2], label = f'$\\tau$ = {tau_dephase}')
            
plt.yticks(
    [-np.pi, -np.pi/2, 0, np.pi/2, np.pi, (3*np.pi)/2, 2*np.pi], 
    ['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$', '$3\pi/2$', '$2\pi$']
)
plt.ylim(-np.pi/2, np.pi/2)
plt.title(f'Optimized $\\tau_{{1}}$')
plt.xlabel('Time')
plt.ylabel('RAD')
plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(res[0][:,0], res[0][:,INDEX.TAU_2.value + 2], label = f'$\\tau$ = {tau_dephase}')
            
plt.yticks(
    [-np.pi, -np.pi/2, 0, np.pi/2, np.pi, (3*np.pi)/2, 2*np.pi], 
    ['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$', '$3\pi/2$', '$2\pi$']
)
plt.ylim(-np.pi/2, np.pi/2)
plt.title(f'Optimized $\\tau_{{2}}$')
plt.xlabel('Time')
plt.ylabel('RAD')
plt.grid()
plt.legend()
plt.show()
