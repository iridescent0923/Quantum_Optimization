# %%
# ==============================
# Standard Library Imports
# ==============================
from enum import Enum
import random

# ==============================
# Third-party Library Imports
# ==============================
import matplotlib.pyplot as plt
from IPython.display import display, Latex
from matplotlib.ticker import MultipleLocator
import numpy as np  # Original numpy
import pennylane as qml
import torch 

# ==============================
# User defined 
# ==============================
import plot_data as pt
import torch_optimizer as tr_opt

# %%
# ==============================
# Setup for Quantum Computations
# ==============================

# PennyLane settings
dev = qml.device('default.mixed', wires=2)

# Define Hamiltonian for quantum computations
H = qml.Hamiltonian(
    coeffs=[-0.5], 
    observables=[
        qml.PauliZ(0) @ qml.PauliZ(1) 
    ]
)

H_1 = qml.Hamiltonian(
    coeffs=[-0.5, -0.5], 
    observables=[
        qml.PauliZ(0), qml.PauliZ(1)
    ]
)

# %% [markdown]
# ## New Hamiltonian
#
# #### Entangler Hamiltonian
#
# $$
# H =
# -0.5 \cdot(
#  \, Z_0 \otimes Z_1 \otimes I_{2} \otimes I_3
#  + \, Z_{0} \otimes I_1 \otimes Z_{2} \otimes I_3
#  + \, I_{0} \otimes Z_1 \otimes Z_{2} \otimes I_{3} \\
#  + \, I_{0} \otimes Z_1 \otimes I_{2} \otimes Z_3
#  + \, I_{0} \otimes I_1 \otimes Z_{2} \otimes Z_3
# )
# $$
#
#
# $$
# where,
# Z = \begin{pmatrix}
# 1 & 0 \\
# 0 & -1
# \end{pmatrix}
# $$

# %% [markdown]
# #### Entangler Hamiltonian_2
#
# $$
# H =
# -0.5 \cdot (
#  \, Z_0 \otimes Z_1 \otimes I_{2} \otimes I_3
#  + \, Z_{0} \otimes I_1 \otimes Z_{2} \otimes I_3
#  + \, Z_{0} \otimes I_1 \otimes I_{2} \otimes Z_3\\
#  + \, I_{0} \otimes Z_1 \otimes Z_{2} \otimes I_{3}
#  + \, I_{0} \otimes Z_1 \otimes I_{2} \otimes Z_3
#  + \, I_{0} \otimes I_1 \otimes Z_{2} \otimes Z_3
# )
# $$
#
#
# $$
# where,
# Z = \begin{pmatrix}
# 1 & 0 \\
# 0 & -1
# \end{pmatrix}
# $$

# %% [markdown]
# #### Phase Accumulator Hamiltonian
#
#
# $$
# H_{1} = -0.5 \cdot (
#     Z_0 + Z_1 + Z_2 + Z_3
# )
# $$
#
#
#
# $$
#
# $$
#
#
# $$
# where,
# Z = \begin{pmatrix} 1 & 0 \\ 0 & -1 \end{pmatrix}
# $$

# %%
# Global Parameters
Tau_global = torch.tensor(0, dtype=torch.float, requires_grad=False)   # Dephase tau
Gamma_ps_global = torch.tensor(0, dtype=torch.float, requires_grad=False)
Paras_global = torch.tensor([0, 0, 0, 0, 0], dtype=torch.float, requires_grad=True)
Phi_global = torch.tensor(0, dtype=torch.float, requires_grad=True)

def Dephase_factor(tau):
    """ 
    Calculate the dephasing factor for a given dephasing time tau.

    Args:
        tau (torch.Tensor): Dephasing time.

    Returns:
        torch.Tensor: Dephasing factor.
    """  
    return 1 - torch.exp(-2 * tau)

# %% [markdown]
# $$
# Let, e^{-t/T_2} = e^{-\tau} \\[1em]
#
# \frac{1}{2}
#
# \begin{bmatrix}
#
# 1 & e^{(i\phi - \tau)} \\
# e^{(-i\phi - \tau)} & 1
#
# \end{bmatrix}
#
# =
#
# \frac{1}{2}
#
# \begin{bmatrix}
#
# 1 & e^{i\phi} \sqrt{1 - \gamma} \\
# e^{-i\phi} \sqrt{1 - \gamma} & 1
#
# \end{bmatrix}
# $$
#
# $$
# \\[1em]
# Then,
# \quad \gamma =
# 1 - e^{-2 \tau}
# $$
#
# $$
# e^{-\tau} = \sqrt{1 - \gamma}
# $$

# %%
class INDEX(Enum):
    THETA_X = 0
    
    PHI_Z1 = 1
    PHI_Z2 = 2
    
    TAU_1 = 3
    TAU_2 = 4

# %%
@qml.qnode(dev, interface='torch', diff_method='backprop')
def circuit(phi):
    global Paras_global, Tau_global
    theta_x = Paras_global[0]

    phi_z = Paras_global[1]

    tau_1 = Paras_global[2]
    tau_2 = torch.pi/4

    gamma_dephase = Dephase_factor(Tau_global)
    
    # Stage_1: RY for pi/2
    qml.RY(torch.pi/2, wires=0)
    qml.RY(torch.pi/2, wires=1)
    
    # Stage_2: Entangler  
    qml.ApproxTimeEvolution(H, tau_1, 1)
    qml.PhaseDamping(gamma_dephase, wires = 0)
    qml.PhaseDamping(gamma_dephase, wires = 1)    
    
    qml.RX(theta_x, wires = 0)    
    qml.RX(theta_x, wires = 1)       

    qml.RY(-torch.pi/2, wires = 0)    
    qml.RY(-torch.pi/2, wires = 1)     

    qml.ApproxTimeEvolution(H, tau_2, 1)
    qml.PhaseDamping(gamma_dephase, wires = 0)
    qml.PhaseDamping(gamma_dephase, wires = 1) 
    
    qml.RY(torch.pi/2, wires = 0)    
    qml.RY(torch.pi/2, wires = 1) 

    # Stage_4: Accumulator
    qml.ApproxTimeEvolution(H_1, phi, 1)
    qml.PhaseDamping(gamma_dephase, wires = 0)
    qml.PhaseDamping(gamma_dephase, wires = 1) 
    
    qml.RZ(phi_z, wires=0)
    qml.RZ(phi_z, wires=1)
    
    qml.RX(torch.pi/(2), wires=0)
    qml.RX(torch.pi/(2), wires=1)
    
    # return qml.state()
    return qml.density_matrix(wires = [0, 1])

# %%
fig, ax = qml.draw_mpl(circuit)(np.pi)

# %%
# @qml.qnode(dev, interface = 'torch', diff_method = 'backprop')
# def Post_selection(phi):

#     global Paras_global, Gamma_ps_global
#     get_density_matrix = circuit(phi)
        
#     # Kraus operator for 2*2 matrix
#     K = torch.tensor([
#         [torch.sqrt(1 - Gamma_ps_global), 0], 
#         [0, 1]
#     ], dtype=torch.complex128)
    
#     I_2 = torch.eye(2)  # 2*2
    
#     num_1 = torch.kron(K, I_2) @ get_density_matrix @ torch.kron(K, I_2).conj().T
#     num_2 = torch.kron(I_2, K) @ get_density_matrix @ torch.kron(I_2, K).conj().T
    
#     den_1 = 2 * torch.trace(num_1)
#     den_2 = 2 * torch.trace(num_2)
    
#     rho_1 = num_1 / den_1
#     rho_2 = num_2 / den_2
    
#     rho_ps = rho_1 + rho_2
    
#     qml.QubitDensityMatrix(rho_ps, wires = [0, 1])
    
#     return qml.density_matrix(wires = [0, 1])

# %%
@qml.qnode(dev, interface = 'torch', diff_method = 'backprop')
def Post_selection(phi):

    global Paras_global, Gamma_ps_global
    get_density_matrix = circuit(phi)
        
    # Kraus operator for 2*2 matrix
    K = torch.tensor([
        [torch.sqrt(1 - Gamma_ps_global), 0], 
        [0, 1]
    ], dtype=torch.complex128)
    
    Numerator = torch.kron(K, K) @ get_density_matrix @ torch.kron(K, K).conj().T
    Denominator = torch.trace(Numerator)
    
    rho_ps = Numerator / Denominator
    
    qml.QubitDensityMatrix(rho_ps, wires = [0, 1])
    
    return qml.density_matrix(wires = [0, 1])

# %% [markdown]
# $$
# K =  \begin{bmatrix}
# \sqrt{1-\gamma_{ps}} & 0 \\
# 0 & 1
# \end{bmatrix}
# $$
#
#
# $$
# \rho_{ps} =
# \frac
# {(K \otimes I) \rho (K \otimes I)^{\dagger}}
# {2Tr[(K \otimes I) \rho (K \otimes I)^{\dagger}]}
#
# +
#
# \frac
# {(I \otimes K) \rho (I \otimes K)^{\dagger}}
# {2Tr[(I \otimes K) \rho (I \otimes K)^{\dagger}]}
# $$

# %%
def set_circuit(desired_tau_dephase, desired_gamma_post_selection):
    """
    Set the global dephasing rate and post-selection rate for the circuit.

    Args:
        desired_tau_dephase (float): Desired dephasing rate tau.
        desired_gamma_post_selection (float): Desired post-selection rate gamma.
    """
    global Tau_global, Gamma_ps_global 
    
    Tau_global = torch.tensor(desired_tau_dephase)
    Gamma_ps_global = torch.tensor([desired_gamma_post_selection])

# %%
def cost_function(paras):
    """ 
    Compute the cost using classical Fisher information for the given parameters.

    Args:
        paras (torch.Tensor): Parameters for quantum gates.

    Returns:
        torch.Tensor: Computed cost.
    """
    global Paras_global, Phi_global
    Paras_global = paras

    CFI = qml.qinfo.classical_fisher(Post_selection)(Phi_global)
    
    return -CFI

# %%
def sweep_cfi(sweep_range, initial_parameters):
    Phi = torch.arange(sweep_range[0], sweep_range[1], sweep_range[2], dtype=torch.float32)
    Data = torch.zeros((len(Phi), 2))
    Data[:,0] = Phi
    
    global Phi_global
    params_tensor = initial_parameters.clone().requires_grad_(True)
    
    for phi_idx in range(len(Phi)):
        Phi_global = Phi[phi_idx].clone().requires_grad_(True)
        
        Data[phi_idx, 1] = -cost_function(params_tensor)
        
    return Data

# %%
def sweep_by_tau(sweep_range, init_par, tau_dephase, gamma_post_selection):
    for tau_idx, tau_current in enumerate(tau_dephase):
        set_circuit(tau_current, gamma_post_selection)
        
        temp = sweep_cfi(sweep_range, init_par).detach().numpy()
        
        if tau_idx == 0:
            Data = np.zeros((len(tau_dephase), len(temp[:,0]), len(temp[0,:])))
            Data[tau_idx][:, :] = temp
        else:
            Data[tau_idx][:, :] = temp
        
    return Data

# %%
import time

def torch_optimization(sweep_range, initial_parameters, method):
    """ 
    Perform optimization using specified optimizer over a range of phi values.

    Args:
        sweep_range (list): Range of phi values for optimization.
        initial_parameters (torch.Tensor): Initial parameters for optimization.
        method (str): Optimization method ('LBFGS' or 'Adam').

    Returns:
        torch.Tensor: Data tensor containing optimization results.
    """
    Phi = torch.arange(sweep_range[0], sweep_range[1], sweep_range[2], dtype=torch.float32)
    Data = torch.zeros((len(Phi), len(initial_parameters) + 2))
    Data[:,0] = Phi
    
    global Phi_global
    params_tensor = initial_parameters.clone().requires_grad_(True)
    
    opt = tr_opt.select_optimizer(method, params_tensor)
    
    def closure():
        opt.zero_grad()
        loss = cost_function(params_tensor)
        loss.backward()
        return loss
       
    steps = 15
    f_logs = [cost_function(params_tensor).item()]
    ftol = 1e-10
        
    start_time = time.time()
    del_accu = 0
    # Begin optimization
    for phi_idx in range(len(Phi)):
        Phi_global = Phi[phi_idx].clone().requires_grad_(True)

        for i in range(steps):
            opt.step(closure)

            fval = cost_function(opt.param_groups[0]['params'][0]).item()
            f_logs.append(fval)
            if np.abs((fval-f_logs[-2])/fval) < ftol:
                break
            
        elapsed_time = time.time() - start_time
        estimated_total_time = (elapsed_time / (phi_idx + 1)) * len(Phi)
        remaining_time = estimated_total_time - elapsed_time
        
        formatted_x = [f"{x:.8f}" for x in opt.param_groups[0]['params'][0].detach().numpy()]
        
        del_CFI = (Data[phi_idx-1, 1]) + fval if phi_idx > 0 else 0
        del_accu += del_CFI
        print(
            "CFI =", f"{-fval:.5f}", 
            "Paras =", formatted_x, 
            f"[eta : {remaining_time / 60:.2f}_min,",
            f"iter_left : {len(Phi) - phi_idx},", 
            f"del_CFI : {del_CFI:.4f}]",
            f"del_accumulated : {del_accu:.4f}"
        )

        Data[phi_idx, 1] = -fval
        Data[phi_idx, 2:] = opt.param_groups[0]['params'][0]        
        
    return Data

# %%
def optimization_by_tau(sweep_range, init_par, tau_dephase, gamma_post_selection, method):
    """ 
    Iterate over different values of tau_dephase and gamma_post_selection for optimization.

    Args:
        sweep_range (list): Range of phi values for optimization.
        init_par (torch.Tensor): Initial parameters for optimization.
        tau_dephase (list): List of dephasing rates tau to iterate over.
        gamma_post_selection (float): Post-selection rate gamma.
        method (str): Optimization method.

    Returns:
        np.ndarray: Numpy array with optimization results for each tau.
    """
    for tau_idx, tau_current in enumerate(tau_dephase):
        set_circuit(tau_current, gamma_post_selection)
        
        temp = torch_optimization(sweep_range, init_par, method).detach().cpu().numpy()
        if tau_idx == 0:
            Data = np.zeros((len(tau_dephase), len(temp[:,0]), len(temp[0,:])))
            Data[tau_idx][:, :] = temp
        else:
            Data[tau_idx][:, :] = temp
            
    return Data

# %%
import time
sweep_range = torch.tensor(
    [1e-2, 2*torch.pi, 1e-2], 
    dtype=torch.float, requires_grad=False
)

init_par = torch.tensor([
    # theta_x
    torch.pi/4, 
    
    # phi_z
    torch.pi/4, 
    
    # tau_1:2
    torch.pi/4, torch.pi/4,
    ], dtype=torch.float)

tau_dephase = 0,
gamma_ps = 0

start_time = time.time()
res = optimization_by_tau(sweep_range, init_par, tau_dephase, gamma_ps, 'LBFGS')
end_time = time.time()

running_time = (end_time - start_time) / 60
# Out:
# CFI = 4.00000 Paras = ['0.78539836', '0.78539789', '-1.57121885', '0.78539819'] [eta : 6.55_min, iter_left : 628, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539836', '0.78539789', '-1.57121885', '0.78539819'] [eta : 5.34_min, iter_left : 627, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539836', '0.78539789', '-1.57121885', '0.78539819'] [eta : 4.85_min, iter_left : 626, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539860', '0.78539777', '-1.57121456', '0.78539819'] [eta : 5.07_min, iter_left : 625, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539860', '0.78539777', '-1.57121456', '0.78539819'] [eta : 4.73_min, iter_left : 624, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539890', '0.78539759', '-1.57120812', '0.78539819'] [eta : 5.16_min, iter_left : 623, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539956', '0.78539693', '-1.57118571', '0.78539819'] [eta : 6.67_min, iter_left : 622, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539968', '0.78539681', '-1.57118177', '0.78539819'] [eta : 6.52_min, iter_left : 621, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539979', '0.78539670', '-1.57117796', '0.78539819'] [eta : 6.52_min, iter_left : 620, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539979', '0.78539616', '-1.57116091', '0.78539819'] [eta : 7.22_min, iter_left : 619, del_CFI : -0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78539979', '0.78539598', '-1.57115555', '0.78539819'] [eta : 7.15_min, iter_left : 618, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539979', '0.78539574', '-1.57114840', '0.78539819'] [eta : 7.14_min, iter_left : 617, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539979', '0.78539568', '-1.57114661', '0.78539819'] [eta : 6.90_min, iter_left : 616, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539979', '0.78539568', '-1.57114661', '0.78539819'] [eta : 6.60_min, iter_left : 615, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539979', '0.78539550', '-1.57114124', '0.78539819'] [eta : 6.52_min, iter_left : 614, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78
del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.58_min, iter_left : 80, del_CFI : -0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.58_min, iter_left : 79, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.57_min, iter_left : 78, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.56_min, iter_left : 77, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.56_min, iter_left : 76, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.55_min, iter_left : 75, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.54_min, iter_left : 74, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.53_min, iter_left : 73, del_CFI : -0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.53_min, iter_left : 72, del_CFI : -0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.52_min, iter_left : 71, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.51_min, iter_left : 70, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.50_min, iter_left : 69, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.50_min, iter_left : 68, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.49_min, iter_left : 67, del_CFI : -0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.48_min, iter_left : 66, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.47_min, iter_left : 65, del_CFI : -0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.47_min, iter_left : 64, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.46_min, iter_left : 63, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.45_min, iter_left : 62, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.44_min, iter_left : 61, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.44_min, iter_left : 60, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.43_min, iter_left : 59, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.42_min, iter_left : 58, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.41_min, iter_left : 57, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.41_min, iter_left : 56, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.40_min, iter_left : 55, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.39_min, iter_left : 54, del_CFI : -0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.38_min, iter_left : 53, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.38_min, iter_left : 52, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.37_min, iter_left : 51, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.36_min, iter_left : 50, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.35_min, iter_left : 49, del_CFI : -0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.35_min, iter_left : 48, del_CFI : 0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.34_min, iter_left : 47, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.33_min, iter_left : 46, del_CFI : -0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.32_min, iter_left : 45, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.32_min, iter_left : 44, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.31_min, iter_left : 43, del_CFI : -0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.30_min, iter_left : 42, del_CFI : 0.0000] del_accumulated : -0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.30_min, iter_left : 41, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.29_min, iter_left : 40, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.28_min, iter_left : 39, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.27_min, iter_left : 38, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.27_min, iter_left : 37, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.26_min, iter_left : 36, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.25_min, iter_left : 35, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.24_min, iter_left : 34, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.24_min, iter_left : 33, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.23_min, iter_left : 32, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.22_min, iter_left : 31, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.21_min, iter_left : 30, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.21_min, iter_left : 29, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.20_min, iter_left : 28, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.19_min, iter_left : 27, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.19_min, iter_left : 26, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.18_min, iter_left : 25, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.17_min, iter_left : 24, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.16_min, iter_left : 23, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.16_min, iter_left : 22, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.15_min, iter_left : 21, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.14_min, iter_left : 20, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.13_min, iter_left : 19, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.13_min, iter_left : 18, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.12_min, iter_left : 17, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.11_min, iter_left : 16, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.10_min, iter_left : 15, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.10_min, iter_left : 14, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.09_min, iter_left : 13, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.08_min, iter_left : 12, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.07_min, iter_left : 11, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.07_min, iter_left : 10, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.06_min, iter_left : 9, del_CFI : -0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.05_min, iter_left : 8, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.04_min, iter_left : 7, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.04_min, iter_left : 6, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.03_min, iter_left : 5, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.02_min, iter_left : 4, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.01_min, iter_left : 3, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.01_min, iter_left : 2, del_CFI : 0.0000] del_accumulated : 0.0000
# CFI = 4.00000 Paras = ['0.78539795', '0.78539413', '-1.57094204', '0.78539819'] [eta : 0.00_min, iter_left : 1, del_CFI : 0.0000] del_accumulated : 0.0000

# %%
np.save(f"result_[{tau_dephase[0]}]_{running_time:.2f}", res)

# %%
len(res[0][0, :])
# Out:
# 6

# %%
plt.plot(res[0][:,0], res[0][:,1], label = f'$\\tau$ = {tau_dephase}')
plt.title(f'CFI at $\gamma_{{ps}} = {gamma_ps}$')
plt.xlabel('Time')
plt.ylabel('CFI')
plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(res[0][:,0], res[0][:,INDEX.THETA_X.value + 2], label = f'$\\tau$ = {tau_dephase}')
            
plt.yticks(
    [-np.pi, -np.pi/2, 0, np.pi/2, np.pi, (3*np.pi)/2, 2*np.pi], 
    ['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$', '$3\pi/2$', '$2\pi$']
)
# plt.ylim(-np.pi/2, np.pi/2)
plt.title(f'Optimized $\\theta_{{x}}$')
plt.xlabel('Time')
plt.ylabel('RAD')
plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(res[0][:,0], res[0][:,INDEX.PHI_Z1.value + 2], label = f'$\\tau$ = {tau_dephase}')
            
plt.yticks(
    [-np.pi, -np.pi/2, 0, np.pi/2, np.pi, (3*np.pi)/2, 2*np.pi], 
    ['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$', '$3\pi/2$', '$2\pi$']
)
# plt.ylim(-np.pi/2, np.pi/2)
plt.title(f'Optimized $\\phi_{{z1}}$')
plt.xlabel('Time')
plt.ylabel('RAD')
plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(res[0][:,0], res[0][:,INDEX.PHI_Z2.value + 2], label = f'$\\tau$ = {tau_dephase}')
            
plt.yticks(
    [-np.pi, -np.pi/2, 0, np.pi/2, np.pi, (3*np.pi)/2, 2*np.pi], 
    ['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$', '$3\pi/2$', '$2\pi$']
)
# plt.ylim(-np.pi/2, np.pi/2)
plt.title(f'Optimized $\\phi_{{z2}}$')
plt.xlabel('Time')
plt.ylabel('RAD')
plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(res[0][:,0], res[0][:,INDEX.TAU_1.value + 2], label = f'$\\tau$ = {tau_dephase}')
            
plt.yticks(
    [-np.pi, -np.pi/2, 0, np.pi/2, np.pi, (3*np.pi)/2, 2*np.pi], 
    ['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$', '$3\pi/2$', '$2\pi$']
)
plt.ylim(-np.pi/2, np.pi/2)
plt.title(f'Optimized $\\tau_{{1}}$')
plt.xlabel('Time')
plt.ylabel('RAD')
plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(res[0][:,0], res[0][:,INDEX.TAU_2.value + 2], label = f'$\\tau$ = {tau_dephase}')
            
plt.yticks(
    [-np.pi, -np.pi/2, 0, np.pi/2, np.pi, (3*np.pi)/2, 2*np.pi], 
    ['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$', '$3\pi/2$', '$2\pi$']
)
plt.ylim(-np.pi/2, np.pi/2)
plt.title(f'Optimized $\\tau_{{2}}$')
plt.xlabel('Time')
plt.ylabel('RAD')
plt.grid()
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/dongukkim/Desktop/Quantum_Workspace/Pennylane_Workspace/Optimization/[2-qubit]/[ps=0]/torch_[0].ipynb Cell 28 line 1
# ----> <a href='vscode-notebook-cell:/Users/dongukkim/Desktop/Quantum_Workspace/Pennylane_Workspace/Optimization/%5B2-qubit%5D/%5Bps%3D0%5D/torch_%5B0%5D.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> plt.plot(res[0][:,0], res[0][:,INDEX.TAU_2.value + 2], label = f'$\\tau$ = {tau_dephase}')
#       <a href='vscode-notebook-cell:/Users/dongukkim/Desktop/Quantum_Workspace/Pennylane_Workspace/Optimization/%5B2-qubit%5D/%5Bps%3D0%5D/torch_%5B0%5D.ipynb#X36sZmlsZQ%3D%3D?line=2'>3</a> plt.yticks(
#       <a href='vscode-notebook-cell:/Users/dongukkim/Desktop/Quantum_Workspace/Pennylane_Workspace/Optimization/%5B2-qubit%5D/%5Bps%3D0%5D/torch_%5B0%5D.ipynb#X36sZmlsZQ%3D%3D?line=3'>4</a>     [-np.pi, -np.pi/2, 0, np.pi/2, np.pi, (3*np.pi)/2, 2*np.pi],
#       <a href='vscode-notebook-cell:/Users/dongukkim/Desktop/Quantum_Workspace/Pennylane_Workspace/Optimization/%5B2-qubit%5D/%5Bps%3D0%5D/torch_%5B0%5D.ipynb#X36sZmlsZQ%3D%3D?line=4'>5</a>     ['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$', '$3\pi/2$', '$2\pi$']
#       <a href='vscode-notebook-cell:/Users/dongukkim/Desktop/Quantum_Workspace/Pennylane_Workspace/Optimization/%5B2-qubit%5D/%5Bps%3D0%5D/torch_%5B0%5D.ipynb#X36sZmlsZQ%3D%3D?line=5'>6</a> )
#       <a href='vscode-notebook-cell:/Users/dongukkim/Desktop/Quantum_Workspace/Pennylane_Workspace/Optimization/%5B2-qubit%5D/%5Bps%3D0%5D/torch_%5B0%5D.ipynb#X36sZmlsZQ%3D%3D?line=6'>7</a> plt.ylim(-np.pi/2, np.pi/2)
#
# IndexError: index 6 is out of bounds for axis 1 with size 6
