# %%
import matplotlib.pyplot as plt
from IPython.display import display, Latex
from matplotlib.ticker import MultipleLocator
import numpy as np  # Original numpy

from enum import Enum

# %%
class INDEX(Enum):
    PHI = 0
    CFI = 1
    
    THETA_X1 = 2
    THETA_X2 = 3
    
    PHI_Z1 = 4
    PHI_Z2 = 5
    PHI_Z3 = 6
    PHI_Z4 = 7
    
    TAU_L1 = 8
    TAU_L2 = 9
    
    TAU_R1 = 10
    TAU_R2 = 11

class DataPlotter:
    def __init__(self, data_in):
        self.data_in = data_in
        
    def plot_cfi(self, tau_dephase=0, gamma_ps=0):        
        plt.plot(
            self.data_in[0][:,INDEX.PHI.value], 
            self.data_in[0][:,INDEX.CFI.value], 
            label = f'$\\tau$ = {tau_dephase}')
        
        plt.title(f'CFI at $\gamma_{{ps}} = {gamma_ps}$')
        plt.xlabel('Time')
        plt.ylabel('CFI')
        plt.grid()
        plt.legend()
        # plt.show()
        
    def plot_theta_x1(self, tau_dephase=0, set_ylim=(0, 0)):
        plt.plot(
            self.data_in[0][:,INDEX.PHI.value], 
            self.data_in[0][:,INDEX.THETA_X1.value], 
            label = f'$\\tau$ = {tau_dephase}')
        
        self.plot_settings(
            title = f'Optimized $\\theta_{{x1}}$',
            ylim = set_ylim
        )

    def plot_theta_x2(self, tau_dephase=0, set_ylim=(0, 0)):
        plt.plot(
            self.data_in[0][:,INDEX.PHI.value], 
            self.data_in[0][:,INDEX.THETA_X2.value], 
            label = f'$\\tau$ = {tau_dephase}')
        
        self.plot_settings(
            title = f'Optimized $\\theta_{{x2}}$',
            ylim = set_ylim
        )
        
    def plot_phi_z1(self, tau_dephase=0, set_ylim=(0, 0)):
        plt.plot(
            self.data_in[0][:,INDEX.PHI.value], 
            self.data_in[0][:,INDEX.PHI_Z1.value], 
            label = f'$\\tau$ = {tau_dephase}')
        
        self.plot_settings(
                    title = f'Optimized $\\phi_{{z1}}$',
                    ylim = set_ylim
        )
        
    def plot_phi_z2(self, tau_dephase=0, set_ylim=(0, 0)):
        plt.plot(
            self.data_in[0][:,INDEX.PHI.value], 
            self.data_in[0][:,INDEX.PHI_Z2.value], 
            label = f'$\\tau$ = {tau_dephase}')
        
        self.plot_settings(
                    title = f'Optimized $\\phi_{{z2}}$',
                    ylim = set_ylim
        )
        
    def plot_phi_z3(self, tau_dephase=0, set_ylim=(0, 0)):
        plt.plot(
            self.data_in[0][:,INDEX.PHI.value], 
            self.data_in[0][:,INDEX.PHI_Z3.value], 
            label = f'$\\tau$ = {tau_dephase}')

        self.plot_settings(
                    title = f'Optimized $\\phi_{{z3}}$',
                    ylim = set_ylim
        )
        
    def plot_phi_z4(self, tau_dephase=0, set_ylim=(0, 0)):
        plt.plot(
            self.data_in[0][:,INDEX.PHI.value], 
            self.data_in[0][:,INDEX.PHI_Z4.value], 
            label = f'$\\tau$ = {tau_dephase}')

        self.plot_settings(
                    title = f'Optimized $\\phi_{{z4}}$',
                    ylim = set_ylim
        )
        
    def plot_tau_L1(self, tau_dephase=0, set_ylim=(0, 0)):
        plt.plot(
            self.data_in[0][:,INDEX.PHI.value], 
            self.data_in[0][:,INDEX.TAU_L1.value], 
            label = f'$\\tau$ = {tau_dephase}')
        
        self.plot_settings(
                    title = f'Optimized $\\tau_{{L1}}$',
                    ylim = set_ylim
        )
        
    def plot_tau_L2(self, tau_dephase=0, set_ylim=(0, 0)):
        plt.plot(
            self.data_in[0][:,INDEX.PHI.value], 
            self.data_in[0][:,INDEX.TAU_L2.value], 
            label = f'$\\tau$ = {tau_dephase}')

        self.plot_settings(
                    title = f'Optimized $\\tau_{{L2}}$',
                    ylim = set_ylim
        )
        
    def plot_tau_R1(self, tau_dephase=0, set_ylim=(0, 0)):
        plt.plot(
            self.data_in[0][:,INDEX.PHI.value], 
            self.data_in[0][:,INDEX.TAU_R1.value], 
            label = f'$\\tau$ = {tau_dephase}')

        self.plot_settings(
                    title = f'Optimized $\\tau_{{R1}}$',
                    ylim = set_ylim
        )
        
    def plot_tau_R2(self, tau_dephase=0, set_ylim=(0, 0)):
        plt.plot(
            self.data_in[0][:,INDEX.PHI.value], 
            self.data_in[0][:,INDEX.TAU_R2.value], 
            label = f'$\\tau$ = {tau_dephase}')

        self.plot_settings(
                    title = f'Optimized $\\tau_{{R2}}$',
                    ylim = set_ylim
        )
        
    def plot_settings(self, title, xlabel='Time', ylabel='Rad', ylim=(-2*np.pi, 2*np.pi)):
        plt.yticks(
            [-np.pi, -3*np.pi/4, -np.pi/2, -np.pi/4, 0, np.pi/4, np.pi/2, 3*np.pi/4, np.pi, (3*np.pi)/2, 2*np.pi, 5*np.pi/2], 
            ['$-\pi$', '$-3\pi/4$', '$-\pi/2$', '$-\pi/4$', '0', '$\pi/4$', '$\pi/2$', '$3\pi/4$', '$\pi$', '$3\pi/2$', '$2\pi$', '$5\pi/2$']
        )
        plt.ylim(ylim)
        plt.title(title)
        plt.xlabel(xlabel)
        plt.ylabel(ylabel)
        plt.grid()
        plt.legend()
        # plt.show()

# %%
data_files = {
    'data_0': 'result_[0].npy',
    'data_0.005': 'result_[0.005].npy',
    'data_0.05': 'result_[0.05].npy',
    'data_0.1': 'result_[0.1].npy',
    'data_0.5': 'result_[0.5].npy'
}

data = {}
for key, file_name in data_files.items():
    data[key] = np.load(file_name)

# %%
for key, dataset in data.items():
    plotter = DataPlotter(dataset)
    plotter.plot_cfi(tau_dephase=key.split('_')[1], gamma_ps=0)
    plt.legend()

# %%
for key, dataset in data.items():
    plotter = DataPlotter(dataset)
    plotter.plot_theta_x1(tau_dephase=key.split('_')[1], set_ylim=(0, 1.5*np.pi/4))

# %%
data['data_0'][0][:, INDEX.TAU_R2.value]
# Out:
# array([0.67009121, 0.67002386, 0.67001122, 0.66999757, 0.6690734 ,
#        0.66906142, 0.66903728, 0.66902518, 0.6688866 , 0.66886485,
#        0.66813606, 0.66796988, 0.66796964, 0.66796958, 0.66795868,
#        0.66786736, 0.66785747, 0.6677705 , 0.66743511, 0.66717243,
#        0.66715449, 0.66715449, 0.66715389, 0.66714317, 0.66701251,
#        0.66698217, 0.66693878, 0.6669386 , 0.66687948, 0.66687948,
#        0.66687948, 0.6668458 , 0.66635776, 0.66634184, 0.66631949,
#        0.66543108, 0.66509509, 0.66422188, 0.66414297, 0.66363466,
#        0.66350794, 0.66322321, 0.66292435, 0.66292399, 0.66292399,
#        0.66292363, 0.66292328, 0.66292292, 0.66292256, 0.66292185,
#        0.66292167, 0.66292167, 0.66292167, 0.66292113, 0.66292024,
#        0.6629197 , 0.6629197 , 0.66291952, 0.66291934, 0.66291898,
#        0.66291845, 0.66291773, 0.66291738, 0.66291738, 0.6629172 ,
#        0.66291684, 0.66291684, 0.66291648, 0.66291612, 0.66291595,
#        0.66280627, 0.66280627, 0.66280627, 0.66280627, 0.66280627,
#        0.66280627, 0.66280627, 0.66280627, 0.66280627, 0.66280627,
#        0.66280627, 0.66280627, 0.66280627, 0.66280627, 0.66280627,
#        0.66280627, 0.66280627, 0.66280627, 0.66280627, 0.66280627,
#        0.66280627, 0.66280627, 0.66280627, 0.66280627, 0.66280627,
#        0.66280627, 0.66280627, 0.66280627, 0.66280627, 0.66280627,
#        0.66280627, 0.66280627, 0.66280627, 0.66280627, 0.66280627,
#        0.66280627, 0.66280627, 0.66280627, 0.66280627, 0.66280627,
#        0.66280627, 0.66280627, 0.66280627, 0.66280627, 0.66280627,
#        0.66280627, 0.66280627, 0.66280627, 0.66280627, 0.66280627,
#        0.66280627, 0.66280633, 0.66280633, 0.66280633, 0.66280633,
#        0.66280633, 0.66280633, 0.66280633, 0.66280633, 0.66280633,
#        0.66280633, 0.66280633, 0.66280633, 0.66280633, 0.66280633,
#        0.66280633, 0.66280633, 0.66280633, 0.66280633, 0.66280633,
#        0.66280633, 0.66280633, 0.66280633, 0.66280633, 0.66280633,
#        0.66280633, 0.66280633, 0.66280633, 0.66280633, 0.66280633,
#        0.66280633, 0.66280633, 0.66280633, 0.66280633, 0.66280633,
#        0.66280633, 0.66280633, 0.66280633, 0.66280633, 0.66280633,
#        0.66280633, 0.66280633, 0.66280633, 0.66280633, 0.66280633,
#        0.66280633, 0.66280633, 0.66280633, 0.66280633, 0.66280633,
#        0.66280633, 0.66280633, 0.66280633, 0.66280633, 0.66280633,
#        0.66280633, 0.66280633, 0.66280633, 0.66280633, 0.66280633,
#        0.66280633, 0.66280633, 0.66280633, 0.66280633, 0.66280633,
#        0.66280633, 0.66280633, 0.66280633])

# %%
for key, dataset in data.items():
    plotter = DataPlotter(dataset)
    plotter.plot_theta_x2(tau_dephase=key.split('_')[1], set_ylim=(-np.pi/4, 3*np.pi/8))

# %%
for key, dataset in data.items():
    plotter = DataPlotter(dataset)
    plotter.plot_phi_z1(tau_dephase=key.split('_')[1], set_ylim=(0, 5*np.pi/2))

# %%
for key, dataset in data.items():
    plotter = DataPlotter(dataset)
    plotter.plot_phi_z2(tau_dephase=key.split('_')[1], set_ylim=(0, 5*np.pi/2))

# %%
for key, dataset in data.items():
    plotter = DataPlotter(dataset)
    plotter.plot_phi_z3(tau_dephase=key.split('_')[1], set_ylim=(0, 5*np.pi/2))

# %%
for key, dataset in data.items():
    plotter = DataPlotter(dataset)
    plotter.plot_phi_z4(tau_dephase=key.split('_')[1], set_ylim=(0, 5*np.pi/2))

# %%
for key, dataset in data.items():
    plotter = DataPlotter(dataset)
    plotter.plot_tau_L1(tau_dephase=key.split('_')[1], set_ylim=(-0.1, 1.5*np.pi/4))

# %%
for key, dataset in data.items():
    plotter = DataPlotter(dataset)
    plotter.plot_tau_L2(tau_dephase=key.split('_')[1], set_ylim=(-0.1, np.pi/4))

# %%
for key, dataset in data.items():
    plotter = DataPlotter(dataset)
    plotter.plot_tau_R1(tau_dephase=key.split('_')[1], set_ylim=(-np.pi/8, 1.5*np.pi/4))

# %%
for key, dataset in data.items():
    plotter = DataPlotter(dataset)
    plotter.plot_tau_R2(tau_dephase=key.split('_')[1], set_ylim=(0.5, 1.2*np.pi/2))
